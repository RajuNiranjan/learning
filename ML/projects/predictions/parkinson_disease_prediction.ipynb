# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

# %%
parkinson_ds  = '../data_sets/parkinsons.data'

parkinson_data = pd.read_csv(parkinson_ds)

# %%
parkinson_data.shape
# Out:
# (195, 24)

# %%
parkinson_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302  ...  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650  ...  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111  ...  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871  ...  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781  ...  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
parkinson_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
X = parkinson_data.drop(columns=['status',"name"], axis=1)

Y = parkinson_data['status']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    train_size=0.8,
    stratify=Y,
    random_state=2
)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %%
model = SVC()

# %%
model.fit(X_train, Y_train)
# Out:
# SVC()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
training_data_accuracy
# Out:
# 0.8141025641025641

# %%
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)
testing_data_accuracy
# Out:
# 0.8461538461538461

# %%
input_data = (
245.51000,262.09000,231.84800,0.00235,0.000010,0.00127,0.00148,0.00380,0.01608,0.14100,0.00906,0.00977,0.01149,0.02719,0.00476,24.60200,0.467489,0.631653,-7.156076,0.127642,2.392122,0.097336

)

input_data_array = np.asarray(input_data).reshape(1, -1)

prediction = model.predict(input_data_array)

if prediction[0] == 1:
    print("Positive")
else:
    print("Negative")
# Out:
# Negative
# e:\learning\ML\projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
